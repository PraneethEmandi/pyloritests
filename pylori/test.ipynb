# %%
from PIL import Image
from collections import Counter

def extract_colors_from_image(image_path, max_colors=256):
    """
    Extract all distinct colors from an image.

    Args:
        image_path (str): Path to the input image.
        max_colors (int): Maximum number of colors to extract. Default is 256.

    Returns:
        list: List of extracted colors in RGB format.
    """
    # Open the image
    img = Image.open(image_path)
    
    # Convert the image to RGB mode (if not already in RGB)
    img = img.convert("RGB")
    
    # Reduce the image size for faster processing (optional)
    img = img.resize((img.width // 2, img.height // 2))

    # Get all pixels
    pixels = list(img.getdata())

    # Count unique colors
    color_count = Counter(pixels)

    # Get the most common colors
    most_common_colors = color_count.most_common(max_colors)

    # Extract the RGB values
    extracted_colors = [color for color, count in most_common_colors]

    return extracted_colors

# Example usage
image_path = "../4.jpg"  # Replace with the path to your image
colors = extract_colors_from_image(image_path)

# Print the extracted colors
print("Extracted Colors:", colors)
# Out:
# Extracted Colors: [(237, 255, 205), (231, 255, 205), (220, 236, 199), (215, 231, 194), (212, 240, 199), (217, 247, 195), (67, 0, 255), (222, 254, 189), (222, 252, 200), (60, 0, 254), (232, 255, 199), (220, 238, 190), (66, 0, 255), (207, 235, 194), (227, 255, 204), (70, 0, 255), (68, 0, 255), (69, 0, 255), (217, 249, 184), (71, 0, 255), (61, 0, 254), (72, 0, 255), (73, 0, 255), (75, 0, 255), (227, 255, 196), (72, 1, 255), (65, 0, 255), (215, 229, 203), (74, 0, 255), (215, 233, 185), (232, 255, 209), (225, 245, 184), (76, 0, 255), (63, 0, 255), (64, 0, 255), (57, 0, 255), (77, 0, 255), (62, 0, 254), (62, 0, 253), (225, 243, 195), (66, 1, 255), (62, 1, 255), (62, 0, 255), (228, 236, 189), (55, 0, 252), (225, 241, 204), (59, 0, 254), (228, 234, 200), (80, 0, 255), (67, 1, 255), (56, 0, 255), (78, 0, 255), (63, 0, 254), (81, 0, 255), (63, 1, 255), (71, 1, 255), (79, 0, 255), (65, 1, 255), (210, 226, 189), (82, 0, 255), (220, 234, 208), (64, 0, 254), (65, 0, 254), (53, 0, 255), (83, 0, 254), (66, 0, 254), (58, 0, 255), (60, 0, 246), (73, 1, 255), (220, 240, 179), (237, 255, 215), (64, 1, 255), (69, 0, 254), (85, 0, 254), (58, 0, 253), (70, 0, 254), (84, 0, 254), (82, 0, 254), (71, 0, 254), (68, 1, 255), (68, 0, 254), (73, 0, 254), (61, 0, 255), (67, 0, 254), (223, 229, 195), (222, 226, 203), (59, 0, 253), (72, 0, 254), (59, 0, 252), (58, 0, 254), (60, 0, 255), (65, 0, 252), (76, 0, 254), (78, 0, 254), (60, 0, 253), (212, 242, 190), (90, 0, 254), (91, 0, 254), (75, 0, 254), (70, 1, 255), (77, 0, 254), (59, 0, 255), (56, 0, 252), (74, 0, 254), (61, 0, 253), (81, 0, 254), (80, 0, 254), (83, 0, 255), (79, 0, 254), (62, 1, 254), (69, 1, 255), (86, 0, 254), (61, 1, 254), (88, 0, 254), (55, 0, 255), (57, 0, 253), (63, 0, 253), (61, 1, 255), (223, 231, 184), (89, 0, 254), (72, 0, 252), (57, 0, 252), (57, 0, 254), (92, 0, 254), (55, 0, 242), (63, 1, 254), (64, 1, 254), (74, 1, 255), (87, 0, 254), (233, 255, 200), (236, 255, 205), (53, 0, 254), (87, 0, 255), (85, 0, 255), (207, 237, 185), (56, 0, 254), (49, 0, 252), (54, 0, 255), (75, 1, 255), (93, 0, 254), (228, 255, 196), (94, 0, 254), (55, 0, 254), (58, 0, 252), (86, 0, 255), (220, 250, 198), (232, 255, 205), (65, 1, 254), (217, 245, 204), (76, 1, 255), (237, 255, 197), (78, 1, 255), (67, 1, 254), (77, 1, 255), (54, 0, 254), (95, 0, 254), (71, 1, 254), (101, 0, 255), (81, 0, 253), (60, 1, 254), (52, 0, 248), (66, 0, 253), (92, 0, 255), (97, 0, 255), (217, 233, 196), (99, 0, 255), (98, 0, 255), (84, 0, 255), (103, 0, 255), (75, 1, 254), (64, 0, 252), (72, 1, 254), (93, 0, 255), (210, 224, 198), (56, 0, 251), (70, 1, 254), (56, 0, 253), (67, 0, 253), (51, 0, 253), (217, 221, 198), (104, 0, 255), (95, 0, 255), (52, 0, 255), (61, 0, 251), (100, 0, 255), (66, 1, 254), (60, 0, 252), (236, 255, 204), (224, 254, 202), (215, 227, 215), (74, 1, 254), (82, 1, 254), (113, 0, 254), (96, 0, 254), (69, 1, 254), (94, 0, 255), (218, 234, 197), (114, 0, 254), (102, 0, 255), (73, 0, 253), (222, 238, 201), (68, 1, 254), (105, 0, 255), (71, 0, 252), (73, 1, 254), (112, 0, 254), (55, 0, 251), (229, 224, 194), (100, 0, 254), (92, 1, 254), (101, 0, 254), (64, 0, 253), (61, 0, 252), (65, 0, 253), (77, 1, 254), (71, 0, 253), (76, 1, 254), (51, 0, 255), (68, 0, 253), (111, 0, 255), (115, 0, 254), (102, 0, 254), (66, 0, 252), (83, 1, 254), (98, 0, 254), (81, 1, 254), (84, 0, 253), (72, 0, 253), (237, 255, 204), (92, 1, 255), (110, 0, 254), (66, 0, 246), (88, 0, 255), (103, 0, 254), (79, 1, 255), (69, 0, 253), (80, 0, 253), (60, 0, 250), (80, 1, 255), (52, 0, 254), (213, 240, 199), (104, 0, 254), (99, 0, 254), (81, 1, 255), (74, 0, 253), (107, 0, 254), (70, 0, 253), (83, 0, 253), (59, 1, 254), (230, 248, 200), (219, 249, 197), (97, 0, 254), (96, 0, 255), (82, 0, 253), (75, 0, 253), (217, 251, 175)]

# %%
from PIL import Image

def replace_violet_blue_with_white(image_path, output_path):
    """
    Replace all violet and blue-like colors in the image with white.

    Args:
        image_path (str): Path to the input image.
        output_path (str): Path to save the modified image.
    """
    # Open the image
    img = Image.open(image_path)
    
    # Convert to RGB mode (if not already in RGB)
    img = img.convert("RGB")
    
    # Load the image data
    pixels = img.load()
    
    # Get the dimensions of the image
    width, height = img.size
    
    # Define the range of violet and blue-like colors (approximate RGB ranges)
    def is_violet_blue(rgb):
        r, g, b = rgb
        # Violet and blue-like colors usually have a high blue component
        return b > 120 and r < 100 and g < 100  # Adjust thresholds as needed

    # Replace violet and blue-like colors with white
    for x in range(width):
        for y in range(height):
            current_color = pixels[x, y]
            if is_violet_blue(current_color):
                pixels[x, y] = (255, 255, 255)  # Replace with white

    # Save the modified image
    img.save(output_path)
    print(f"Modified image saved to {output_path}")

# Example usage
image_path = "../4.jpg"  # Replace with the path to your input image
output_path = "output_image3.jpg"  # Path to save the modified image
replace_violet_blue_with_white(image_path, output_path)
# Out:
# Modified image saved to output_image3.jpg

# %%
from PIL import Image

def replace_bright_colors_with_white(image_path, output_path, brightness_threshold=500):
    """
    Replace all bright colors in an image with white.

    Args:
        image_path (str): Path to the input image.
        output_path (str): Path to save the modified image.
        brightness_threshold (int): Minimum sum of RGB components to classify as bright.
    """
    # Open the image
    img = Image.open(image_path)
    
    # Convert to RGB mode (if not already in RGB)
    img = img.convert("RGB")
    
    # Load the image data
    pixels = img.load()
    
    # Get the dimensions of the image
    width, height = img.size
    
    # Replace bright colors with white
    for x in range(width):
        for y in range(height):
            r, g, b = pixels[x, y]
            if r + g + b > brightness_threshold:  # Check brightness
                pixels[x, y] = (255, 255, 255)  # Replace with white

    # Save the modified image
    img.save(output_path)
    print(f"Modified image saved to {output_path}")

# Example usage
image_path = "../4.jpg"  # Replace with the path to your input image
output_path = "output_image2.jpg"  # Path to save the modified image
replace_bright_colors_with_white(image_path, output_path)
# Out:
# Modified image saved to output_image2.jpg

# %%
from PIL import Image
from collections import Counter
import webcolors

def extract_colors_from_image(image_path, max_colors=256):
    """
    Extract all distinct colors from an image.

    Args:
        image_path (str): Path to the input image.
        max_colors (int): Maximum number of colors to extract. Default is 256.

    Returns:
        list: List of extracted colors in RGB format.
    """
    # Open the image
    img = Image.open(image_path)
    
    # Convert the image to RGB mode (if not already in RGB)
    img = img.convert("RGB")
    
    # Reduce the image size for faster processing (optional)
    img = img.resize((img.width // 2, img.height // 2))

    # Get all pixels
    pixels = list(img.getdata())

    # Count unique colors
    color_count = Counter(pixels)

    # Get the most common colors
    most_common_colors = color_count.most_common(max_colors)

    # Extract the RGB values
    extracted_colors = [color for color, count in most_common_colors]

    return extracted_colors

def get_closest_color_name(rgb):
    """
    Get the closest color name from CSS3 for an RGB value.

    Args:
        rgb (tuple): RGB color value.

    Returns:
        str: Closest color name.
    """
    css3_names = webcolors.names("css3")
    min_diff = float('inf')
    closest_color = None

    for color_name in css3_names:
        try:
            hex_code = webcolors.name_to_hex(color_name)
            r, g, b = webcolors.hex_to_rgb(hex_code)
            diff = ((rgb[0] - r) ** 2 + (rgb[1] - g) ** 2 + (rgb[2] - b) ** 2) ** 0.5
            if diff < min_diff:
                min_diff = diff
                closest_color = color_name
        except ValueError:
            continue

    return closest_color

# Example usage
image_path = "../4.jpg"  # Replace with the path to your image
colors = extract_colors_from_image(image_path)

print("Extracted Colors and Names:")
for color in colors:
    color_name = get_closest_color_name(color)
    print(f"RGB: {color}, Closest CSS3 Color Name: {color_name}")
# Out:
# Extracted Colors and Names:
# RGB: (237, 255, 205), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (231, 255, 205), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (220, 236, 199), Closest CSS3 Color Name: gainsboro
# RGB: (215, 231, 194), Closest CSS3 Color Name: lightgray
# RGB: (212, 240, 199), Closest CSS3 Color Name: gainsboro
# RGB: (217, 247, 195), Closest CSS3 Color Name: palegoldenrod
# RGB: (67, 0, 255), Closest CSS3 Color Name: blue
# RGB: (222, 254, 189), Closest CSS3 Color Name: palegoldenrod
# RGB: (222, 252, 200), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (60, 0, 254), Closest CSS3 Color Name: blue
# RGB: (232, 255, 199), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (220, 238, 190), Closest CSS3 Color Name: palegoldenrod
# RGB: (66, 0, 255), Closest CSS3 Color Name: blue
# RGB: (207, 235, 194), Closest CSS3 Color Name: lightgray
# RGB: (227, 255, 204), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (70, 0, 255), Closest CSS3 Color Name: blue
# RGB: (68, 0, 255), Closest CSS3 Color Name: blue
# RGB: (69, 0, 255), Closest CSS3 Color Name: blue
# RGB: (217, 249, 184), Closest CSS3 Color Name: palegoldenrod
# RGB: (71, 0, 255), Closest CSS3 Color Name: blue
# RGB: (61, 0, 254), Closest CSS3 Color Name: blue
# RGB: (72, 0, 255), Closest CSS3 Color Name: blue
# RGB: (73, 0, 255), Closest CSS3 Color Name: blue
# RGB: (75, 0, 255), Closest CSS3 Color Name: blue
# RGB: (227, 255, 196), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (72, 1, 255), Closest CSS3 Color Name: blue
# RGB: (65, 0, 255), Closest CSS3 Color Name: blue
# RGB: (215, 229, 203), Closest CSS3 Color Name: gainsboro
# RGB: (74, 0, 255), Closest CSS3 Color Name: blue
# RGB: (215, 233, 185), Closest CSS3 Color Name: palegoldenrod
# RGB: (232, 255, 209), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (225, 245, 184), Closest CSS3 Color Name: palegoldenrod
# RGB: (76, 0, 255), Closest CSS3 Color Name: blue
# RGB: (63, 0, 255), Closest CSS3 Color Name: blue
# RGB: (64, 0, 255), Closest CSS3 Color Name: blue
# RGB: (57, 0, 255), Closest CSS3 Color Name: blue
# RGB: (77, 0, 255), Closest CSS3 Color Name: blue
# RGB: (62, 0, 254), Closest CSS3 Color Name: blue
# RGB: (62, 0, 253), Closest CSS3 Color Name: blue
# RGB: (225, 243, 195), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (66, 1, 255), Closest CSS3 Color Name: blue
# RGB: (62, 1, 255), Closest CSS3 Color Name: blue
# RGB: (62, 0, 255), Closest CSS3 Color Name: blue
# RGB: (228, 236, 189), Closest CSS3 Color Name: palegoldenrod
# RGB: (55, 0, 252), Closest CSS3 Color Name: blue
# RGB: (225, 241, 204), Closest CSS3 Color Name: beige
# RGB: (59, 0, 254), Closest CSS3 Color Name: blue
# RGB: (228, 234, 200), Closest CSS3 Color Name: gainsboro
# RGB: (80, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (67, 1, 255), Closest CSS3 Color Name: blue
# RGB: (56, 0, 255), Closest CSS3 Color Name: blue
# RGB: (78, 0, 255), Closest CSS3 Color Name: blue
# RGB: (63, 0, 254), Closest CSS3 Color Name: blue
# RGB: (81, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (63, 1, 255), Closest CSS3 Color Name: blue
# RGB: (71, 1, 255), Closest CSS3 Color Name: blue
# RGB: (79, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (65, 1, 255), Closest CSS3 Color Name: blue
# RGB: (210, 226, 189), Closest CSS3 Color Name: lightgray
# RGB: (82, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (220, 234, 208), Closest CSS3 Color Name: gainsboro
# RGB: (64, 0, 254), Closest CSS3 Color Name: blue
# RGB: (65, 0, 254), Closest CSS3 Color Name: blue
# RGB: (53, 0, 255), Closest CSS3 Color Name: blue
# RGB: (83, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (66, 0, 254), Closest CSS3 Color Name: blue
# RGB: (58, 0, 255), Closest CSS3 Color Name: blue
# RGB: (60, 0, 246), Closest CSS3 Color Name: blue
# RGB: (73, 1, 255), Closest CSS3 Color Name: blue
# RGB: (220, 240, 179), Closest CSS3 Color Name: palegoldenrod
# RGB: (237, 255, 215), Closest CSS3 Color Name: beige
# RGB: (64, 1, 255), Closest CSS3 Color Name: blue
# RGB: (69, 0, 254), Closest CSS3 Color Name: blue
# RGB: (85, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (58, 0, 253), Closest CSS3 Color Name: blue
# RGB: (70, 0, 254), Closest CSS3 Color Name: blue
# RGB: (84, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (82, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (71, 0, 254), Closest CSS3 Color Name: blue
# RGB: (68, 1, 255), Closest CSS3 Color Name: blue
# RGB: (68, 0, 254), Closest CSS3 Color Name: blue
# RGB: (73, 0, 254), Closest CSS3 Color Name: blue
# RGB: (61, 0, 255), Closest CSS3 Color Name: blue
# RGB: (67, 0, 254), Closest CSS3 Color Name: blue
# RGB: (223, 229, 195), Closest CSS3 Color Name: gainsboro
# RGB: (222, 226, 203), Closest CSS3 Color Name: gainsboro
# RGB: (59, 0, 253), Closest CSS3 Color Name: blue
# RGB: (72, 0, 254), Closest CSS3 Color Name: blue
# RGB: (59, 0, 252), Closest CSS3 Color Name: blue
# RGB: (58, 0, 254), Closest CSS3 Color Name: blue
# RGB: (60, 0, 255), Closest CSS3 Color Name: blue
# RGB: (65, 0, 252), Closest CSS3 Color Name: blue
# RGB: (76, 0, 254), Closest CSS3 Color Name: blue
# RGB: (78, 0, 254), Closest CSS3 Color Name: blue
# RGB: (60, 0, 253), Closest CSS3 Color Name: blue
# RGB: (212, 242, 190), Closest CSS3 Color Name: palegoldenrod
# RGB: (90, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (91, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (75, 0, 254), Closest CSS3 Color Name: blue
# RGB: (70, 1, 255), Closest CSS3 Color Name: blue
# RGB: (77, 0, 254), Closest CSS3 Color Name: blue
# RGB: (59, 0, 255), Closest CSS3 Color Name: blue
# RGB: (56, 0, 252), Closest CSS3 Color Name: blue
# RGB: (74, 0, 254), Closest CSS3 Color Name: blue
# RGB: (61, 0, 253), Closest CSS3 Color Name: blue
# RGB: (81, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (80, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (83, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (79, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (62, 1, 254), Closest CSS3 Color Name: blue
# RGB: (69, 1, 255), Closest CSS3 Color Name: blue
# RGB: (86, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (61, 1, 254), Closest CSS3 Color Name: blue
# RGB: (88, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (55, 0, 255), Closest CSS3 Color Name: blue
# RGB: (57, 0, 253), Closest CSS3 Color Name: blue
# RGB: (63, 0, 253), Closest CSS3 Color Name: blue
# RGB: (61, 1, 255), Closest CSS3 Color Name: blue
# RGB: (223, 231, 184), Closest CSS3 Color Name: palegoldenrod
# RGB: (89, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (72, 0, 252), Closest CSS3 Color Name: blue
# RGB: (57, 0, 252), Closest CSS3 Color Name: blue
# RGB: (57, 0, 254), Closest CSS3 Color Name: blue
# RGB: (92, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (55, 0, 242), Closest CSS3 Color Name: blue
# RGB: (63, 1, 254), Closest CSS3 Color Name: blue
# RGB: (64, 1, 254), Closest CSS3 Color Name: blue
# RGB: (74, 1, 255), Closest CSS3 Color Name: blue
# RGB: (87, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (233, 255, 200), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (236, 255, 205), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (53, 0, 254), Closest CSS3 Color Name: blue
# RGB: (87, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (85, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (207, 237, 185), Closest CSS3 Color Name: palegoldenrod
# RGB: (56, 0, 254), Closest CSS3 Color Name: blue
# RGB: (49, 0, 252), Closest CSS3 Color Name: blue
# RGB: (54, 0, 255), Closest CSS3 Color Name: blue
# RGB: (75, 1, 255), Closest CSS3 Color Name: blue
# RGB: (93, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (228, 255, 196), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (94, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (55, 0, 254), Closest CSS3 Color Name: blue
# RGB: (58, 0, 252), Closest CSS3 Color Name: blue
# RGB: (86, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (220, 250, 198), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (232, 255, 205), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (65, 1, 254), Closest CSS3 Color Name: blue
# RGB: (217, 245, 204), Closest CSS3 Color Name: gainsboro
# RGB: (76, 1, 255), Closest CSS3 Color Name: blue
# RGB: (237, 255, 197), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (78, 1, 255), Closest CSS3 Color Name: blue
# RGB: (67, 1, 254), Closest CSS3 Color Name: blue
# RGB: (77, 1, 255), Closest CSS3 Color Name: blue
# RGB: (54, 0, 254), Closest CSS3 Color Name: blue
# RGB: (95, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (71, 1, 254), Closest CSS3 Color Name: blue
# RGB: (101, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (81, 0, 253), Closest CSS3 Color Name: blueviolet
# RGB: (60, 1, 254), Closest CSS3 Color Name: blue
# RGB: (52, 0, 248), Closest CSS3 Color Name: blue
# RGB: (66, 0, 253), Closest CSS3 Color Name: blue
# RGB: (92, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (97, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (217, 233, 196), Closest CSS3 Color Name: lightgray
# RGB: (99, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (98, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (84, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (103, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (75, 1, 254), Closest CSS3 Color Name: blue
# RGB: (64, 0, 252), Closest CSS3 Color Name: blue
# RGB: (72, 1, 254), Closest CSS3 Color Name: blue
# RGB: (93, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (210, 224, 198), Closest CSS3 Color Name: lightgray
# RGB: (56, 0, 251), Closest CSS3 Color Name: blue
# RGB: (70, 1, 254), Closest CSS3 Color Name: blue
# RGB: (56, 0, 253), Closest CSS3 Color Name: blue
# RGB: (67, 0, 253), Closest CSS3 Color Name: blue
# RGB: (51, 0, 253), Closest CSS3 Color Name: blue
# RGB: (217, 221, 198), Closest CSS3 Color Name: lightgray
# RGB: (104, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (95, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (52, 0, 255), Closest CSS3 Color Name: blue
# RGB: (61, 0, 251), Closest CSS3 Color Name: blue
# RGB: (100, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (66, 1, 254), Closest CSS3 Color Name: blue
# RGB: (60, 0, 252), Closest CSS3 Color Name: blue
# RGB: (236, 255, 204), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (224, 254, 202), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (215, 227, 215), Closest CSS3 Color Name: gainsboro
# RGB: (74, 1, 254), Closest CSS3 Color Name: blue
# RGB: (82, 1, 254), Closest CSS3 Color Name: blueviolet
# RGB: (113, 0, 254), Closest CSS3 Color Name: darkviolet
# RGB: (96, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (69, 1, 254), Closest CSS3 Color Name: blue
# RGB: (94, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (218, 234, 197), Closest CSS3 Color Name: gainsboro
# RGB: (114, 0, 254), Closest CSS3 Color Name: darkviolet
# RGB: (102, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (73, 0, 253), Closest CSS3 Color Name: blue
# RGB: (222, 238, 201), Closest CSS3 Color Name: gainsboro
# RGB: (68, 1, 254), Closest CSS3 Color Name: blue
# RGB: (105, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (71, 0, 252), Closest CSS3 Color Name: blue
# RGB: (73, 1, 254), Closest CSS3 Color Name: blue
# RGB: (112, 0, 254), Closest CSS3 Color Name: darkviolet
# RGB: (55, 0, 251), Closest CSS3 Color Name: blue
# RGB: (229, 224, 194), Closest CSS3 Color Name: wheat
# RGB: (100, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (92, 1, 254), Closest CSS3 Color Name: blueviolet
# RGB: (101, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (64, 0, 253), Closest CSS3 Color Name: blue
# RGB: (61, 0, 252), Closest CSS3 Color Name: blue
# RGB: (65, 0, 253), Closest CSS3 Color Name: blue
# RGB: (77, 1, 254), Closest CSS3 Color Name: blue
# RGB: (71, 0, 253), Closest CSS3 Color Name: blue
# RGB: (76, 1, 254), Closest CSS3 Color Name: blue
# RGB: (51, 0, 255), Closest CSS3 Color Name: blue
# RGB: (68, 0, 253), Closest CSS3 Color Name: blue
# RGB: (111, 0, 255), Closest CSS3 Color Name: darkviolet
# RGB: (115, 0, 254), Closest CSS3 Color Name: darkviolet
# RGB: (102, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (66, 0, 252), Closest CSS3 Color Name: blue
# RGB: (83, 1, 254), Closest CSS3 Color Name: blueviolet
# RGB: (98, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (81, 1, 254), Closest CSS3 Color Name: blueviolet
# RGB: (84, 0, 253), Closest CSS3 Color Name: blueviolet
# RGB: (72, 0, 253), Closest CSS3 Color Name: blue
# RGB: (237, 255, 204), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (92, 1, 255), Closest CSS3 Color Name: blueviolet
# RGB: (110, 0, 254), Closest CSS3 Color Name: darkviolet
# RGB: (66, 0, 246), Closest CSS3 Color Name: blue
# RGB: (88, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (103, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (79, 1, 255), Closest CSS3 Color Name: blueviolet
# RGB: (69, 0, 253), Closest CSS3 Color Name: blue
# RGB: (80, 0, 253), Closest CSS3 Color Name: blueviolet
# RGB: (60, 0, 250), Closest CSS3 Color Name: blue
# RGB: (80, 1, 255), Closest CSS3 Color Name: blueviolet
# RGB: (52, 0, 254), Closest CSS3 Color Name: blue
# RGB: (213, 240, 199), Closest CSS3 Color Name: gainsboro
# RGB: (104, 0, 254), Closest CSS3 Color Name: darkviolet
# RGB: (99, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (81, 1, 255), Closest CSS3 Color Name: blueviolet
# RGB: (74, 0, 253), Closest CSS3 Color Name: blue
# RGB: (107, 0, 254), Closest CSS3 Color Name: darkviolet
# RGB: (70, 0, 253), Closest CSS3 Color Name: blue
# RGB: (83, 0, 253), Closest CSS3 Color Name: blueviolet
# RGB: (59, 1, 254), Closest CSS3 Color Name: blue
# RGB: (230, 248, 200), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (219, 249, 197), Closest CSS3 Color Name: lightgoldenrodyellow
# RGB: (97, 0, 254), Closest CSS3 Color Name: blueviolet
# RGB: (96, 0, 255), Closest CSS3 Color Name: blueviolet
# RGB: (82, 0, 253), Closest CSS3 Color Name: blueviolet
# RGB: (75, 0, 253), Closest CSS3 Color Name: blue
# RGB: (217, 251, 175), Closest CSS3 Color Name: palegoldenrod

# %%
from PIL import Image
import webcolors

def get_closest_color_name(rgb):
    """
    Get the closest CSS3 color name for an RGB value.

    Args:
        rgb (tuple): RGB color value.

    Returns:
        str: Closest CSS3 color name.
    """
    css3_names = webcolors.names("css3")
    min_diff = float('inf')
    closest_color = None

    for color_name in css3_names:
        try:
            hex_code = webcolors.name_to_hex(color_name)
            r, g, b = webcolors.hex_to_rgb(hex_code)
            diff = ((rgb[0] - r) ** 2 + (rgb[1] - g) ** 2 + (rgb[2] - b) ** 2) ** 0.5
            if diff < min_diff:
                min_diff = diff
                closest_color = color_name
        except ValueError:
            continue

    return closest_color

def replace_colors_with_black(image_path, output_path):
    """
    Replace all colors similar to specified CSS3 color names with black.

    Args:
        image_path (str): Path to the input image.
        output_path (str): Path to save the modified image.
    """
    # Open the image
    img = Image.open(image_path)
    img = img.convert("RGB")  # Ensure the image is in RGB format
    pixels = img.load()
    width, height = img.size

    # List of target color names
    target_colors = {"lightgoldenrodyellow", "gainsboro", "lightgray", "palegoldenrod"}

    # Iterate through each pixel
    for x in range(width):
        for y in range(height):
            current_color = pixels[x, y]
            closest_color_name = get_closest_color_name(current_color)
            if closest_color_name in target_colors:
                pixels[x, y] = (0, 0, 0)  # Replace with black

    # Save the modified image
    img.save(output_path)
    print(f"Modified image saved to {output_path}")

# Example usage
image_path = "../4.jpg"  # Replace with your image path
output_path = "output_image.jpg"  # Path to save the modified image
replace_colors_with_black(image_path, output_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 63
#      61 image_path = "../4.jpg"  # Replace with your image path
#      62 output_path = "output_image.jpg"  # Path to save the modified image
# ---> 63 replace_colors_with_black(image_path, output_path)
#
# Cell In[16], line 52, in replace_colors_with_black(image_path, output_path)
#      50 for y in range(height):
#      51     current_color = pixels[x, y]
# ---> 52     closest_color_name = get_closest_color_name(current_color)
#      53     if closest_color_name in target_colors:
#      54         pixels[x, y] = (0, 0, 0)  # Replace with black
#
# Cell In[16], line 21, in get_closest_color_name(rgb)
#      19 try:
#      20     hex_code = webcolors.name_to_hex(color_name)
# ---> 21     r, g, b = webcolors.hex_to_rgb(hex_code)
#      22     diff = ((rgb[0] - r) ** 2 + (rgb[1] - g) ** 2 + (rgb[2] - b) ** 2) ** 0.5
#      23     if diff < min_diff:
#
# File c:\Users\prane\anaconda3\py\envs\acci\Lib\site-packages\webcolors\_conversion.py:178, in hex_to_rgb(hex_value)
#     158 """
#     159 Convert a hexadecimal color value to a 3-:class:`tuple` of :class:`int` suitable
#     160 for use in an ``rgb()`` triplet specifying that color.
#    (...)
#     175
#     176 """
#     177 int_value = int(normalize_hex(hex_value)[1:], 16)
# --> 178 return IntegerRGB(int_value >> 16, int_value >> 8 & 0xFF, int_value & 0xFF)
#
# File <string>:1, in <lambda>(_cls, red, green, blue)
#
# KeyboardInterrupt:
